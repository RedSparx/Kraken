# %% [markdown]
# # Plot of the Beta Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

Beta = lambda x,a,b: np.power(x,(a-1))*np.power((1-x),(b-1));

# %%
#ab_Values=[(1,1), (1,2), (3,5),(0.4,0.3), (0.5,0.5)]
x=np.linspace(0,1,100)
for ab in ab_Values:
    a,b = ab
    plt.plot(Beta(x,a,b)/np.sum(Beta(x,a,b)))
plt.show()
